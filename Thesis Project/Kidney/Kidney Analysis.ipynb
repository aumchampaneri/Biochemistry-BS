# %% [markdown]
# This file exists to test analysis of the kidney data

# %%
import scanpy as sc

# Load the kidney data
kidney = sc.read_h5ad("/Users/aumchampaneri/PycharmProjects/Biochemistry-BS/Thesis Project/Kidney/KidneyData.h5ad")

# %%
kidney.var
# Out:
#                  exist_in_Lake2021  exist_in_Muto2021  exist_in_Stewart2019  \
# gene_id
# ENSG00000121410               True               True                  True
# ENSG00000268895               True               True                  True
# ENSG00000148584               True               True                  True
# ENSG00000175899               True               True                  True
# ENSG00000245105               True               True                  True
# ...                            ...                ...                   ...
# ENSG00000074755               True               True                  True
# ENSG00000036549               True               True                  True
# ENSG00000270533               True              False                 False
# ENSG00000272920              False               True                  True
# ENSG00000266919              False              False                 False
#
# ...

# %%
ensembl{

}

sc.pl.dotplot(kidney, ensembl, groupby='cell_type')
