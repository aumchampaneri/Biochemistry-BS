# %% [markdown]
# This file exists to test analysis of the kidney data

# %%
import scanpy as sc

# Load the kidney data
kidney = sc.read_h5ad("/Volumes/CHAMPANERI/Databases/MouseKidneyData.h5ad")

# %%
kidney.var
# Out:
#                     feature_is_filtered feature_name feature_reference  \
# ENSMUSG00000026315                False     Serpinb8   NCBITaxon:10090
# ENSMUSG00000063558                False         Aox1   NCBITaxon:10090
# ENSMUSG00000001138                False        Cnnm3   NCBITaxon:10090
# ENSMUSG00000001143                False       Lman2l   NCBITaxon:10090
# ENSMUSG00000079610                False      Ankrd39   NCBITaxon:10090
# ...                                 ...          ...               ...
# ENSMUSG00000069053                False        Uba1y   NCBITaxon:10090
# ENSMUSG00000096768                False      Gm47283   NCBITaxon:10090
# ENSMUSG00000095366                False      Gm21860   NCBITaxon:10090
# ENSMUSG00000099876                False      Gm29650   NCBITaxon:10090
# ENSMUSG00000103234                False      Gm37158   NCBITaxon:10090
#
#                    feature_biotype feature_length    feature_type
# ENSMUSG00000026315            gene           2096  protein_coding
# ENSMUSG00000063558            gene           5426  protein_coding
# ENSMUSG00000001138            gene           1006  protein_coding
# ENSMUSG00000001143            gene           1843  protein_coding
# ENSMUSG00000079610            gene           1276  protein_coding
# ...                            ...            ...             ...
# ENSMUSG00000069053            gene           3711  protein_coding
# ENSMUSG00000096768            gene            774          lncRNA
# ENSMUSG00000095366            gene            745          lncRNA
# ENSMUSG00000099876            gene            742          lncRNA
# ENSMUSG00000103234            gene           5704             TEC
#
# [16641 rows x 6 columns]

# %%
gene_id = {
    "C4bp": "ENSMUSG00000026405",
    "Cfh": "ENSMUSG00000026365",
    "C1d": "ENSMUSG00000000581",
    "C4a": "ENSMUSG00000015451",
    "C3": "ENSMUSG00000024164",
    "Cfb": "ENSMUSG00000090231",
    "C8g": "ENSMUSG00000015083",
    "Cfi": "ENSMUSG00000058952",
    "C1qb": "ENSMUSG00000036905",
    "C8a": "ENSMUSG00000035031",
    "C3ar1": "ENSMUSG00000040552",
    "C5ar1": "ENSMUSG00000049130",
    "C5ar2": "ENSMUSG00000074361"
}

sc.pl.dotplot(kidney, gene_id, groupby='cell_type')
sc.pl.dotplot(kidney, gene_id, groupby='tissue')
sc.pl.dotplot(kidney, gene_id, groupby='development_stage')

# %%
gene_id = {
    # "C4bp": "ENSMUSG00000026405",
    "Cfh": "ENSMUSG00000026365",
    # "C1d": "ENSMUSG00000000581",
    # "C4a": "ENSMUSG00000015451",
    "C3": "ENSMUSG00000024164",
    # "Cfb": "ENSMUSG00000090231",
    # "C8g": "ENSMUSG00000015083",
    # "Cfi": "ENSMUSG00000058952",
    # "C1qb": "ENSMUSG00000036905",
    # "C8a": "ENSMUSG00000035031",
    "C3ar1": "ENSMUSG00000040552",
    "C5ar1": "ENSMUSG00000049130",
    "C5ar2": "ENSMUSG00000074361"
}

sc.pl.dotplot(kidney, gene_id, groupby='cell_type')
sc.pl.dotplot(kidney, gene_id, groupby='tissue')
sc.pl.dotplot(kidney, gene_id, groupby='development_stage')
