# %%
import scanpy as sc

# Load the kidney data
kidney = sc.read_h5ad("/Volumes/CHAMPANERI/Databases/KidneyData.h5ad")

sc.pp.recipe_zheng17(kidney, plot=True)
# Out:
# /Users/aumchampaneri/.pyenv/versions/miniconda3-latest/lib/python3.12/site-packages/scanpy/preprocessing/_recipes.py:187: FutureWarning: Use sc.pp.highly_variable_genes instead
#   filter_result = filter_genes_dispersion(
# /Users/aumchampaneri/.pyenv/versions/miniconda3-latest/lib/python3.12/site-packages/scanpy/preprocessing/_recipes.py:193: FutureWarning: Use sc.pl.highly_variable_genes instead
#   ppp.filter_genes_dispersion(filter_result, log=True)
# /Users/aumchampaneri/.pyenv/versions/miniconda3-latest/lib/python3.12/site-packages/scanpy/preprocessing/_normalization.py:235: UserWarning: Some cells have zero counts
#   warn(UserWarning("Some cells have zero counts"))

# %%
kidney.var
# Out:
#                  exist_in_Lake2021  exist_in_Muto2021  exist_in_Stewart2019  \
# gene_id
# ENSG00000148584               True               True                  True
# ENSG00000175899               True               True                  True
# ENSG00000090861              False              False                  True
# ENSG00000146386               True               True                  True
# ENSG00000234695              False              False                  True
# ...                            ...                ...                   ...
# ENSG00000267454              False              False                  True
# ENSG00000182348               True               True                  True
# ENSG00000124203               True               True                  True
# ENSG00000228623              False              False                  True
# ENSG00000153975              False              False                  True
#
# ...
